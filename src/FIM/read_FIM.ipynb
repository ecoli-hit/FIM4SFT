# %%
import json 
import torch
import numpy

# %%
path = "/data/mxy/Finstruction/output/test/FIM_entire.pt"

FIM = torch.load(path)
print(FIM)
# Out:
# {'module.model.embed_tokens.weight': tensor([[0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00, 0.0000e+00,
#          0.0000e+00],
#         [4.5611e-07, 4.6142e-08, 6.5309e-08,  ..., 2.7909e-07, 8.1935e-07,
#          4.1472e-08],
#         [3.9951e-08, 9.0247e-08, 2.0030e-09,  ..., 4.6441e-09, 2.9703e-09,
#          6.3253e-09],
#         ...,
#         [0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00, 0.0000e+00,
#          0.0000e+00],
#         [0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00, 0.0000e+00,
#          0.0000e+00],
#         [0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00, 0.0000e+00,
#          0.0000e+00]]), 'module.model.layers.0.self_attn.q_proj.weight': tensor([[1.8634e-16, 7.1202e-17, 2.1473e-18,  ..., 1.9440e-17, 3.4531e-17,
#          1.5403e-17],
#         [5.6553e-17, 3.2830e-17, 1.3727e-18,  ..., 6.9113e-17, 1.9495e-17,
#          1.7432e-17],
#         [5.0852e-16, 6.5614e-17, 1.0326e-18,  ..., 5.4187e-17, 7.3337e-17,
# ...

# %%
for k,v in FIM.items():
    print(k)


# import transformers
# model = transformers.AutoModelForCausalLM.from_pretrained("/data/mxy/models/llama2-7b-hf")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 for k,v in FIM.items():
#       2         print(k)
#       5 # import transformers
#       6 # model = transformers.AutoModelForCausalLM.from_pretrained("/data/mxy/models/llama2-7b-hf")
#
# NameError: name 'FIM' is not defined
